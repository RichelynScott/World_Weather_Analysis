# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy


cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key. The config file containing the key runs easier in the same folder as the working file.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1


for i, city in enumerate(cities):
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    print(f"Processing Record {record_count} | {city}")
    
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        #Index 0 after weather because description is in a single listed dictionary in the JSON file.
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | umm ruwabah
# City not found. Skipping...
# Processing Record 2 | port alfred
# Processing Record 3 | nanakuli
# Processing Record 4 | yumen
# Processing Record 5 | souillac
# Processing Record 6 | hobart
# Processing Record 7 | pangai
# Processing Record 8 | punta arenas
# Processing Record 9 | tautira
# Processing Record 10 | bredasdorp
# Processing Record 11 | abu dhabi
# Processing Record 12 | salinopolis
# Processing Record 13 | opuwo
# Processing Record 14 | praia
# Processing Record 15 | hermanus
# Processing Record 16 | axim
# Processing Record 17 | bad freienwalde
# Processing Record 18 | taixing
# Processing Record 19 | tsihombe
# City not found. Skipping...
# Processing Record 20 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 | alta floresta
# Processing Record 22 | mataura
# Processing Record 23 | korla
# Processing Record 24 | ushuaia
# Processing Record 25 | mbaiki
# ...

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Alfred      ZA -33.5906   26.8910     64.60        35           0
# 1      Nanakuli      US  21.3906 -158.1547     84.15        56          40
# 2         Yumen      CN  40.2833   97.2000     58.30        23          78
# 3      Souillac      MU -20.5167   57.5167     71.37        84          58
# 4        Hobart      AU -42.8794  147.3294     52.27        82          75
# 5        Pangai      TO -19.8000 -174.3500     77.61        70           4
# 6  Punta Arenas      CL -53.1500  -70.9167     41.11        75           0
# 7       Tautira      PF -17.7333 -149.1500     86.02        73          47
# 8    Bredasdorp      ZA -34.5322   20.0403     58.28        34           4
# 9     Abu Dhabi      AE  24.4667   54.3667     91.42        79           0
#
#    Wind Speed Current Description
# 0        8.68           clear sky
# 1       18.12    scattered clouds
# 2       12.15       broken clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
